# %%
import requests as req
import json
from citipy import citipy # downloaded from https://pypi.python.org/pypi/citipy
# https://github.com/wingchen/citipy for how to use it and more info about it

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# coordinates: (latitude (horizontal), longitude (vertical))
    #coordinate range: ([-90,90], [-180, 180])
city = citipy.nearest_city(-100, 90).city_name
country = citipy.nearest_city(-100, 90).country_code

test = [[city, country], [1, 2]]
test[0]
# Out:
# ['albany', 'au']

# %%
# url, api key for openweathermap (OWM)
url = ' http://api.openweathermap.org/data/2.5/weather' #For how to use OWM's api: https://openweathermap.org/current
apiKey = 'c8e2baf63c2571f94bf9d95c94483400' # my requested api key

payload_Test = {'APPID':apiKey, 'units':'imperial', 'q': 'albany,au'} # q doesn't seem to be case sensitive


testResp = req.get(url, params=payload_Test)
weather = testResp.json()

weather
# Out:
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -35.02, 'lon': 117.89},
#  'dt': 1512462308,
#  'id': 2077963,
#  'main': {'grnd_level': 1012.94,
#   'humidity': 69,
#   'pressure': 1012.94,
#   'sea_level': 1025.67,
#   'temp': 66.52,
#   'temp_max': 66.52,
#   'temp_min': 66.52},
#  'name': 'Albany',
#  'sys': {'country': 'AU',
#   'message': 0.1647,
#   'sunrise': 1512420439,
#   'sunset': 1512472274},
#  'weather': [{'description': 'few clouds',
#    'icon': '02d',
#    'id': 801,
#    'main': 'Clouds'}],
#  'wind': {'deg': 196.503, 'speed': 13.47}}

# %%
# Sample of 500 countries from citipy
sample_ls = []
city_ls = []
country_ls = []
Lati_ls = []
Longi_ls = []

#loop to fill the sample list
#TEST for 10 samples
while len(sample_ls) < 10:
    Lati = np.random.uniform(low = -90, high = 90)
    Longi = np.random.uniform(low = -180, high = 180)

    #get nearest city name and country code (in case city name is common one)
    city = citipy.nearest_city(Lati, Longi).city_name
    country = citipy.nearest_city(Lati, Longi).country_code

    #check if city name is in the sample list
    duplicate = False
    for entry in sample_ls:
        if city == entry[0] and country == entry [1]:
            duplicate = True
            break
        else:
            continue
    if duplicate == False:
        #storing Latitude and Longitude in case I need to make sure range of each is OK
        Lati_ls.append(Lati)
        Longi_ls.append(Longi)
        city_ls.append(city)
        country_ls.append(country)
        sample_ls.append([city, country])

#dataframe of the sample of cities
columns=['Country', 'Date', 'TimeStamp', 'Cloudiness', 'Humidity', 'Latitude', 'Longitude', 'Max Temp', 'Wind Speed (mph)']
citySample_df = pd.DataFrame(index=city_ls, columns=columns)
#adding country code in 
citySample_df['Country'] = country_ls

citySample_df
# Out:
#             Country Date TimeStamp Cloudiness Humidity Latitude Longitude  \
# rikitea          pf  NaN       NaN        NaN      NaN      NaN       NaN
# narsaq           gl  NaN       NaN        NaN      NaN      NaN       NaN
# noumea           nc  NaN       NaN        NaN      NaN      NaN       NaN
# chuy             uy  NaN       NaN        NaN      NaN      NaN       NaN
# jamestown        sh  NaN       NaN        NaN      NaN      NaN       NaN
# kapaa            us  NaN       NaN        NaN      NaN      NaN       NaN
# nikolskoye       ru  NaN       NaN        NaN      NaN      NaN       NaN
# grand-lahou      ci  NaN       NaN        NaN      NaN      NaN       NaN
# kavieng          pg  NaN       NaN        NaN      NaN      NaN       NaN
# taolanaro        mg  NaN       NaN        NaN      NaN      NaN       NaN
#
#             Max Temp Wind Speed (mph)
# rikitea          NaN              NaN
# narsaq           NaN              NaN
# noumea           NaN              NaN
# chuy             NaN              NaN
# jamestown        NaN              NaN
# kapaa            NaN              NaN
# nikolskoye       NaN              NaN
# grand-lahou      NaN              NaN
# kavieng          NaN              NaN
# taolanaro        NaN              NaN

# %%
# url, api key for openweathermap (OWM)
url = ' http://api.openweathermap.org/data/2.5/weather' #For how to use OWM's api: https://openweathermap.org/current
apiKey = 'c8e2baf63c2571f94bf9d95c94483400' # my requested api key

# loop through dataframe to get values for each index
count = 0
for index, row in citySample_df.iterrows():
    payload_sampl = {'APPID':apiKey, 'units':'imperial', 'q': index} # q doesn't seem to be case sensitive
    weather = req.get(url, params=payload_sampl).json()
    try:     
        if weather['cod'] != '404': #'cod' seems to equal '404' if city isn't found in OWM. 'cod' == 200 otherwise 
            row['Country'] = weather['sys']['country']
            row['TimeStamp'] = weather['dt']
            row['Latitude'] = weather['coord']['lat']
            row['Longitude'] = weather['coord']['lon']
            row['Max Temp'] = weather['main']['temp_max']
            row['Humidity'] = weather['main']['humidity']
            row['Cloudiness'] = weather['clouds']['all'] #find measure of cloudiness
            row['Wind Speed (mph)'] = weather['wind']['speed']
        else:
            citySample_df.drop(index, inplace=True)
    except ValueError:
        citySample_df.drop(index, inplace=True)
        print('There was a ValueError!')
        continue
        
    count += 1

citySample_df
# Out:
#             Country Date   TimeStamp Cloudiness Humidity Latitude Longitude  \
# rikitea          PF  NaN  1512465622         80       99   -23.12   -134.97
# narsaq           GL  NaN  1512463800          0       52    60.92    -46.05
# noumea           NC  NaN  1512464400          0       61   -22.28    166.46
# chuy             UY  NaN  1512465282          0       92    -33.7    -53.46
# jamestown        US  NaN  1512464160         90       75     42.1    -79.24
# kapaa            US  NaN  1512464160         90       73    22.08   -159.32
# grand-lahou      CI  NaN  1512465624         56       96     5.14     -5.02
# kavieng          PG  NaN  1512465283         56       95    -2.57     150.8
#
#             Max Temp Wind Speed (mph)
# rikitea         77.8             4.23
# narsaq          19.4             5.82
# noumea          78.8             6.93
# chuy           62.32            11.43
# jamestown       48.2            13.87
# kapaa           73.4            11.41
# grand-lahou    78.16              3.6
# kavieng        87.16             16.8

# %%
# Formatting citySample dataframe
    #drop cases where row is all NaN just in case
citySample_df.dropna(axis=0, how='all', inplace=True)

        #format date from unix timestamp 
citySample_df['TimeStamp'] = pd.to_datetime(citySample_df['TimeStamp'], unit='s')

citySample_df['Date'] = [d.date() for d in citySample_df['TimeStamp']]

citySample_df
# Out:
#             Country        Date           TimeStamp Cloudiness Humidity  \
# rikitea          PF  2017-12-05 2017-12-05 09:20:22         80       99
# narsaq           GL  2017-12-05 2017-12-05 08:50:00          0       52
# noumea           NC  2017-12-05 2017-12-05 09:00:00          0       61
# chuy             UY  2017-12-05 2017-12-05 09:14:42          0       92
# jamestown        US  2017-12-05 2017-12-05 08:56:00         90       75
# kapaa            US  2017-12-05 2017-12-05 08:56:00         90       73
# grand-lahou      CI  2017-12-05 2017-12-05 09:20:24         56       96
# kavieng          PG  2017-12-05 2017-12-05 09:14:43         56       95
#
#             Latitude Longitude Max Temp Wind Speed (mph)
# rikitea       -23.12   -134.97     77.8             4.23
# narsaq         60.92    -46.05     19.4             5.82
# noumea        -22.28    166.46     78.8             6.93
# chuy           -33.7    -53.46    62.32            11.43
# jamestown       42.1    -79.24     48.2            13.87
# kapaa          22.08   -159.32     73.4            11.41
# grand-lahou     5.14     -5.02    78.16              3.6
# kavieng        -2.57     150.8    87.16             16.8

# %%
#Scatterplot of Temperature (F) vs. Latitude
sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Max Temp'], edgecolor='black', alpha=0.5)

#Set titles and font sizes
plt.title('Max Temperature vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Max Temperature (F)', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Scatterplot of Humidity (%) vs. Latitude

sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Humidity'], edgecolor='black', alpha=0.5)

#Set titles and font sizes
plt.title('Humidity vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Humidity (%)', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#Scatterplot of Cloudiness (%) vs. Latitude

sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Cloudiness'], edgecolor='black', alpha=0.5)

#Set titles
plt.title('Cloudiness vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Cloudiness', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Scatterplot of Wind Speed (mph) vs. Latitude

sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Wind Speed (mph)'], edgecolor='black', alpha=0.5)

# Set titles
plt.title('Wind Speed vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Wind Speed (mph)', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
