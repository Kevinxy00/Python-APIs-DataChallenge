# %%
#Dependencies
import requests as req
import json
# pip install citipy
from citipy import citipy # downloaded from https://pypi.python.org/pypi/citipy
# https://github.com/wingchen/citipy for how to use it and more info about it

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# coordinates: (latitude (horizontal), longitude (vertical))
    #coordinate range: ([-90,90], [-180, 180])
city = citipy.nearest_city(-100, 90).city_name
country = citipy.nearest_city(-100, 90).country_code

# Testing to see if coordinates work 
test = [[city, country]]
test[0]
# Out:
# ['albany', 'au']

# %%
# url, api key for openweathermap (OWM)
url = ' http://api.openweathermap.org/data/2.5/weather' #For how to use OWM's api: https://openweathermap.org/current
apiKey = 'c8e2baf63c2571f94bf9d95c94483400' # my requested api key

payload_Test = {'APPID':apiKey, 'units':'imperial', 'q': str(test[0][0]) + ',' + str(test[0][1])} # q doesn't seem to be case sensitive


testResp = req.get(url, params=payload_Test)
weather = testResp.json()

# Testing to see if OpenWeatherMap can find test city and country
weather
# Out:
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -35.02, 'lon': 117.89},
#  'dt': 1512600235,
#  'id': 2077963,
#  'main': {'grnd_level': 1022.33,
#   'humidity': 70,
#   'pressure': 1022.33,
#   'sea_level': 1035.24,
#   'temp': 60.8,
#   'temp_max': 60.8,
#   'temp_min': 60.8},
#  'name': 'Albany',
#  'sys': {'country': 'AU',
#   'message': 0.1676,
#   'sunrise': 1512506839,
#   'sunset': 1512558754},
#  'weather': [{'description': 'few clouds',
#    'icon': '02n',
#    'id': 801,
#    'main': 'Clouds'}],
#  'wind': {'deg': 109.503, 'speed': 4.54}}

# %%
# Sample of 500 countries from citipy
sample_ls = []
city_ls = []
country_ls = []
Lati_ls = []
Longi_ls = []

#loop to fill the sample list
#TEST for 100 samples
while len(sample_ls) < 100:
    Lati = np.random.uniform(low = -90, high = 90)
    Longi = np.random.uniform(low = -180, high = 180)

    #get nearest city name and country code (in case city name is common one)
    city = citipy.nearest_city(Lati, Longi).city_name
    country = citipy.nearest_city(Lati, Longi).country_code

    #check if city name is in the sample list
    duplicate = False
    for entry in sample_ls:
        if city == entry[0] and country == entry [1]:
            duplicate = True
            break
        else:
            continue
    if duplicate == False:
        #storing Latitude and Longitude in case I need to make sure range of each is OK
        Lati_ls.append(Lati)
        Longi_ls.append(Longi)
        city_ls.append(city)
        country_ls.append(country)
        sample_ls.append([city, country])

#dataframe of the sample of cities
columns=['Country', 'Date', 'TimeStamp', 'Cloudiness', 'Humidity', 'Latitude', 'Longitude', 'Max Temp', 'Wind Speed (mph)']
citySample_df = pd.DataFrame(index=city_ls, columns=columns)
#adding country code in 
citySample_df['Country'] = country_ls

citySample_df
# Out:
#                        Country Date TimeStamp Cloudiness Humidity Latitude  \
# comodoro rivadavia          ar  NaN       NaN        NaN      NaN      NaN
# puerto colombia             co  NaN       NaN        NaN      NaN      NaN
# busselton                   au  NaN       NaN        NaN      NaN      NaN
# touros                      br  NaN       NaN        NaN      NaN      NaN
# hobart                      au  NaN       NaN        NaN      NaN      NaN
# bredasdorp                  za  NaN       NaN        NaN      NaN      NaN
# new norfolk                 au  NaN       NaN        NaN      NaN      NaN
# punta arenas                cl  NaN       NaN        NaN      NaN      NaN
# bathsheba                   bb  NaN       NaN        NaN      NaN      NaN
# ponta do sol                pt  NaN       NaN        NaN      NaN      NaN
# carnarvon                   au  NaN       NaN        NaN      NaN      NaN
# magadan                     ru  NaN       NaN        NaN      NaN      NaN
# muros                       es  NaN       NaN        NaN      NaN      NaN
# nemuro                      jp  NaN       NaN        NaN      NaN      NaN
# hasaki                      jp  NaN       NaN        NaN      NaN      NaN
# manati                      cu  NaN       NaN        NaN      NaN      NaN
# ekhabi                      ru  NaN       NaN        NaN      NaN      NaN
# key biscayne                us  NaN       NaN        NaN      NaN      NaN
# chunskiy                    ru  NaN       NaN        NaN      NaN      NaN
# black river                 jm  NaN       NaN        NaN      NaN      NaN
# esperance                   au  NaN       NaN        NaN      NaN      NaN
# acajutla                    sv  NaN       NaN        NaN      NaN      NaN
# yellowknife                 ca  NaN       NaN        NaN      NaN      NaN
# port elizabeth              za  NaN       NaN        NaN      NaN      NaN
# chuy                        uy  NaN       NaN        NaN      NaN      NaN
# maniitsoq                   gl  NaN       NaN        NaN      NaN      NaN
# sentyabrskiy                ru  NaN       NaN        NaN      NaN      NaN
# batagay-alyta               ru  NaN       NaN        NaN      NaN      NaN
# vardo                       no  NaN       NaN        NaN      NaN      NaN
# rikitea                     pf  NaN       NaN        NaN      NaN      NaN
# ...                        ...  ...       ...        ...      ...      ...
# qaanaaq                     gl  NaN       NaN        NaN      NaN      NaN
# faanui                      pf  NaN       NaN        NaN      NaN      NaN
# bluff                       nz  NaN       NaN        NaN      NaN      NaN
# george                      za  NaN       NaN        NaN      NaN      NaN
# ancud                       cl  NaN       NaN        NaN      NaN      NaN
# fortuna                     us  NaN       NaN        NaN      NaN      NaN
# la palma                    pa  NaN       NaN        NaN      NaN      NaN
# kodiak                      us  NaN       NaN        NaN      NaN      NaN
# mahebourg                   mu  NaN       NaN        NaN      NaN      NaN
# parfino                     ru  NaN       NaN        NaN      NaN      NaN
# tasiilaq                    gl  NaN       NaN        NaN      NaN      NaN
# kulhudhuffushi              mv  NaN       NaN        NaN      NaN      NaN
# vostok                      ru  NaN       NaN        NaN      NaN      NaN
# saint-francois              gp  NaN       NaN        NaN      NaN      NaN
# san nicolas                 ph  NaN       NaN        NaN      NaN      NaN
# hilo                        us  NaN       NaN        NaN      NaN      NaN
# ascension                   bo  NaN       NaN        NaN      NaN      NaN
# katra                       in  NaN       NaN        NaN      NaN      NaN
# tonj                        sd  NaN       NaN        NaN      NaN      NaN
# aksu                        cn  NaN       NaN        NaN      NaN      NaN
# san-pedro                   ci  NaN       NaN        NaN      NaN      NaN
# tuktoyaktuk                 ca  NaN       NaN        NaN      NaN      NaN
# tumannyy                    ru  NaN       NaN        NaN      NaN      NaN
# iqaluit                     ca  NaN       NaN        NaN      NaN      NaN
# tabiauea                    ki  NaN       NaN        NaN      NaN      NaN
# hithadhoo                   mv  NaN       NaN        NaN      NaN      NaN
# grand river south east      mu  NaN       NaN        NaN      NaN      NaN
# codajas                     br  NaN       NaN        NaN      NaN      NaN
# bethel                      us  NaN       NaN        NaN      NaN      NaN
# rawson                      ar  NaN       NaN        NaN      NaN      NaN
#
#                        Longitude Max Temp Wind Speed (mph)
# comodoro rivadavia           NaN      NaN              NaN
# puerto colombia              NaN      NaN              NaN
# busselton                    NaN      NaN              NaN
# touros                       NaN      NaN              NaN
# hobart                       NaN      NaN              NaN
# bredasdorp                   NaN      NaN              NaN
# new norfolk                  NaN      NaN              NaN
# punta arenas                 NaN      NaN              NaN
# bathsheba                    NaN      NaN              NaN
# ponta do sol                 NaN      NaN              NaN
# carnarvon                    NaN      NaN              NaN
# magadan                      NaN      NaN              NaN
# muros                        NaN      NaN              NaN
# nemuro                       NaN      NaN              NaN
# hasaki                       NaN      NaN              NaN
# manati                       NaN      NaN              NaN
# ekhabi                       NaN      NaN              NaN
# key biscayne                 NaN      NaN              NaN
# chunskiy                     NaN      NaN              NaN
# black river                  NaN      NaN              NaN
# esperance                    NaN      NaN              NaN
# acajutla                     NaN      NaN              NaN
# yellowknife                  NaN      NaN              NaN
# port elizabeth               NaN      NaN              NaN
# chuy                         NaN      NaN              NaN
# maniitsoq                    NaN      NaN              NaN
# sentyabrskiy                 NaN      NaN              NaN
# batagay-alyta                NaN      NaN              NaN
# vardo                        NaN      NaN              NaN
# rikitea                      NaN      NaN              NaN
# ...                          ...      ...              ...
# qaanaaq                      NaN      NaN              NaN
# faanui                       NaN      NaN              NaN
# bluff                        NaN      NaN              NaN
# george                       NaN      NaN              NaN
# ancud                        NaN      NaN              NaN
# fortuna                      NaN      NaN              NaN
# la palma                     NaN      NaN              NaN
# kodiak                       NaN      NaN              NaN
# mahebourg                    NaN      NaN              NaN
# parfino                      NaN      NaN              NaN
# tasiilaq                     NaN      NaN              NaN
# kulhudhuffushi               NaN      NaN              NaN
# vostok                       NaN      NaN              NaN
# saint-francois               NaN      NaN              NaN
# san nicolas                  NaN      NaN              NaN
# hilo                         NaN      NaN              NaN
# ascension                    NaN      NaN              NaN
# katra                        NaN      NaN              NaN
# tonj                         NaN      NaN              NaN
# aksu                         NaN      NaN              NaN
# san-pedro                    NaN      NaN              NaN
# tuktoyaktuk                  NaN      NaN              NaN
# tumannyy                     NaN      NaN              NaN
# iqaluit                      NaN      NaN              NaN
# tabiauea                     NaN      NaN              NaN
# hithadhoo                    NaN      NaN              NaN
# grand river south east       NaN      NaN              NaN
# codajas                      NaN      NaN              NaN
# bethel                       NaN      NaN              NaN
# rawson                       NaN      NaN              NaN
#
# [100 rows x 9 columns]

# %%
# url, api key for openweathermap (OWM)
url = ' http://api.openweathermap.org/data/2.5/weather' #For how to use OWM's api: https://openweathermap.org/current
apiKey = 'c8e2baf63c2571f94bf9d95c94483400' # my requested api key

# loop through dataframe to get values for each index
count = 0
drop_count = 0 # count the number of dropped values 
for index, row in citySample_df.iterrows():
    #print log of each city as it's being processed. 
    print('Processing Record Number ' + str(count+1) + ' of ' + str(len(citySample_df)) + ' | ' + index)
    
    #get weather data based on city and country
    payload_sampl = {'APPID':apiKey, 'units':'imperial', 'q': index + ',' + row['Country']} 
        # q doesn't seem to be case sensitive
    weather = req.get(url, params=payload_sampl)
    weather_json = weather.json()
    try:     
        if weather_json['cod'] != '404': #'cod' seems to equal '404' if city isn't found in OWM. 'cod' == 200 otherwise. 
            row['TimeStamp'] = weather_json['dt']
            row['Latitude'] = weather_json['coord']['lat']
            row['Longitude'] = weather_json['coord']['lon']
            row['Max Temp'] = weather_json['main']['temp_max']
            row['Humidity'] = weather_json['main']['humidity']
            row['Cloudiness'] = weather_json['clouds']['all'] #find measure of cloudiness
            row['Wind Speed (mph)'] = weather_json['wind']['speed']
            print(weather.url)
        else:
            citySample_df.drop(index, inplace=True)
            drop_count += 1
            print('City Not Found! Dropping the Row in the DataFrame! | ' + str(drop_count)\
                  + ' city/cities have been dropped.\n')
    except ValueError:
        citySample_df.drop(index, inplace=True)
        print('There was a ValueError!')
        continue
        
    count += 1
print('\n' + str(drop_count) + ' row(s) have been dropped due to absence in the OWM api.')
citySample_df
# Out:
# Processing Record Number 1 of 88 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=comodoro+rivadavia%2CAR
# Processing Record Number 2 of 88 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=puerto+colombia%2CCO
# Processing Record Number 3 of 88 | busselton
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=busselton%2CAU
# Processing Record Number 4 of 88 | touros
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=touros%2CBR
# Processing Record Number 5 of 88 | hobart
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=hobart%2CAU
# Processing Record Number 6 of 88 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=bredasdorp%2CZA
# Processing Record Number 7 of 88 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=new+norfolk%2CAU
# Processing Record Number 8 of 88 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=punta+arenas%2CCL
# Processing Record Number 9 of 88 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=bathsheba%2CBB
# Processing Record Number 10 of 88 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=ponta+do+sol%2CPT
# Processing Record Number 11 of 88 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=carnarvon%2CAU
# Processing Record Number 12 of 88 | magadan
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=magadan%2CRU
# Processing Record Number 13 of 88 | muros
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=muros%2CES
# Processing Record Number 14 of 88 | nemuro
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=nemuro%2CJP
# Processing Record Number 15 of 88 | hasaki
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=hasaki%2CJP
# Processing Record Number 16 of 88 | manati
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=manati%2CCU
# Processing Record Number 17 of 88 | key biscayne
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=key+biscayne%2Cus
# Processing Record Number 18 of 88 | chunskiy
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=chunskiy%2Cru
# Processing Record Number 19 of 88 | black river
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=black+river%2Cjm
# Processing Record Number 20 of 88 | esperance
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=esperance%2Cau
# Processing Record Number 21 of 88 | acajutla
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=acajutla%2Csv
# Processing Record Number 22 of 88 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=yellowknife%2Cca
# Processing Record Number 23 of 88 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=port+elizabeth%2Cza
# Processing Record Number 24 of 88 | chuy
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=chuy%2Cuy
# Processing Record Number 25 of 88 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=maniitsoq%2Cgl
# Processing Record Number 26 of 88 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=batagay-alyta%2Cru
# Processing Record Number 27 of 88 | vardo
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=vardo%2Cno
# Processing Record Number 28 of 88 | rikitea
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=rikitea%2Cpf
# Processing Record Number 29 of 88 | kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=kanniyakumari%2Cin
# Processing Record Number 30 of 88 | bilibino
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=bilibino%2Cru
# Processing Record Number 31 of 88 | vaini
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=vaini%2Cto
# Processing Record Number 32 of 88 | san patricio
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=san+patricio%2Cmx
# Processing Record Number 33 of 88 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=bengkulu%2Cid
# Processing Record Number 34 of 88 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=severo-kurilsk%2Cru
# Processing Record Number 35 of 88 | rajula
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=rajula%2Cin
# Processing Record Number 36 of 88 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q
| hithadhoo
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=hithadhoo%2Cmv
# Processing Record Number 86 of 88 | codajas
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=codajas%2Cbr
# Processing Record Number 87 of 88 | bethel
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=bethel%2Cus
# Processing Record Number 88 of 88 | rawson
# http://api.openweathermap.org/data/2.5/weather?APPID=c8e2baf63c2571f94bf9d95c94483400&units=imperial&q=rawson%2Car
#
# 0 row(s) have been dropped due to absence in the OWM api.
#                    Country Date   TimeStamp Cloudiness Humidity Latitude  \
# comodoro rivadavia      AR  NaN  1512597600         20       62   -45.87
# puerto colombia         CO  NaN  1512597600         75       83    10.99
# busselton               AU  NaN  1512600363          0      100   -33.65
# touros                  BR  NaN  1512600395         36       88     -5.2
# hobart                  AU  NaN  1512597600         75       63   -42.88
# bredasdorp              ZA  NaN  1512597600          0       77   -34.53
# new norfolk             AU  NaN  1512597600         75       63   -42.78
# punta arenas            CL  NaN  1512597600         75       53   -53.15
# bathsheba               BB  NaN  1512597600         20       78    13.22
# ponta do sol            PT  NaN  1512599400         75       77    32.67
# carnarvon               AU  NaN  1512600359          0       77   -24.87
# magadan                 RU  NaN  1512597600          0       82    59.57
# muros                   ES  NaN  1512599400          0       57    42.78
# nemuro                  JP  NaN  1512600397          0      100    43.32
# hasaki                  JP  NaN  1512597600         40      100    35.73
# manati                  CU  NaN  1512600397         80      100    21.31
# key biscayne            us  NaN  1512597360         20       74    25.69
# chunskiy                ru  NaN  1512600398         92       74    56.08
# black river             jm  NaN  1512597600         20       79    18.03
# esperance               au  NaN  1512600355          0       73   -33.87
# acajutla                sv  NaN  1512597000          0       63    13.59
# yellowknife             ca  NaN  1512597960         75       84    62.46
# port elizabeth          za  NaN  1512597600         90       77   -33.92
# chuy                    uy  NaN  1512600400         24       94    -33.7
# maniitsoq               gl  NaN  1512600400         92       95    65.42
# batagay-alyta           ru  NaN  1512600400         44       71     67.8
# vardo                   no  NaN  1512597000         90       92    70.37
# rikitea                 pf  NaN  1512600353         56      100   -23.12
# kanniyakumari           in  NaN  1512600401         68      100     8.08
# bilibino                ru  NaN  1512600401         44       55    68.05
# ...                    ...  ...         ...        ...      ...      ...
# puerto ayora            ec  NaN  1512597600         40       54    -0.74
# hobyo                   so  NaN  1512600408          0       77     5.35
# arraial do cabo         br  NaN  1512600351         92       89   -22.97
# kapaa                   us  NaN  1512597360         20       60    22.08
# qaanaaq                 gl  NaN  1512600339         68       94    77.48
# faanui                  pf  NaN  1512600349         64      100   -16.48
# bluff                   nz  NaN  1512600348          0       94    -46.6
# george                  za  NaN  1512597600          0       93   -33.96
# ancud                   cl  NaN  1512600409         88       71   -41.87
# fortuna                 us  NaN  1512599700          1       62     40.6
# la palma                pa  NaN  1512600410         80      100      8.4
# kodiak                  us  NaN  1512597180          1       80    57.79
# mahebourg               mu  NaN  1512597600         75       83   -20.41
# parfino                 ru  NaN  1512600410         88       93    57.97
# tasiilaq                gl  NaN  1512597000          0       47    65.61
# kulhudhuffushi          mv  NaN  1512600411         88      100     6.62
# vostok                  ru  NaN  1512600411         12       72    46.49
# saint-francois          gp  NaN  1512597600         20       74    16.25
# san nicolas             ph  NaN  1512597600         20       94    18.17
# hilo                    us  NaN  1512597360         20       50    19.73
# ascension               bo  NaN  1512600412         68       91    -15.7
# katra                   in  NaN  1512600412          0       69    32.98
# aksu                    cn  NaN  1512600413         44       66    41.12
# san-pedro               ci  NaN  1512597600         20       83     4.75
# tuktoyaktuk             ca  NaN  1512597600         75       92    69.45
# iqaluit                 ca  NaN  1512597600         90       92    63.75
# hithadhoo               mv  NaN  1512600414          0      100     -0.6
# codajas                 br  NaN  1512600414         56       90    -3.84
# bethel                  us  NaN  1512597360          1       47    41.37
# rawson                  ar  NaN  1512600415          0       91    -43.3
#
#                    Longitude Max Temp Wind Speed (mph)
# comodoro rivadavia     -67.5     57.2            21.92
# puerto colombia       -74.95     84.2            10.29
# busselton             115.33    60.89            14.72
# touros                -35.46    78.08            10.47
# hobart                147.33     60.8              4.7
# bredasdorp             20.04       68             20.8
# new norfolk           147.06     60.8              4.7
# punta arenas          -70.92       50            32.21
# bathsheba             -59.52     80.6            13.87
# ponta do sol           -17.1     64.4             8.05
# carnarvon             113.63     77.9            16.51
# magadan                150.8   -22.01             4.47
# muros                  -9.06     48.2             5.82
# nemuro                145.57     31.1             14.5
# hasaki                140.83     35.6             5.82
# manati                -76.94    78.89            16.51
# key biscayne          -80.16     78.8             6.93
# chunskiy               99.63    23.54            10.69
# black river           -77.85     84.2            12.75
# esperance              121.9    61.97             5.66
# acajutla              -89.83     91.4             6.93
# yellowknife          -114.35      3.2             8.05
# port elizabeth         25.57     66.2            23.04
# chuy                  -53.46    67.55             6.33
# maniitsoq              -52.9    30.83            28.25
# batagay-alyta         130.41   -25.61             3.09
# vardo                  31.11     21.2            11.41
# rikitea              -134.97    77.99            17.74
# kanniyakumari          77.57    80.15             6.44
# bilibino              166.44    -5.89             4.09
# ...                      ...      ...              ...
# puerto ayora          -90.35     82.4            14.99
# hobyo                  48.53    77.27            17.74
# arraial do cabo       -42.03    74.07            13.82
# kapaa                -159.32     73.4             8.05
# qaanaaq               -69.36      8.1             2.19
# faanui               -151.75    81.45            13.04
# bluff                 168.33    63.77             5.55
# george                 22.46     57.2             3.36
# ancud                 -73.82    60.26              2.3
# fortuna              -124.16     57.2             6.93
# la palma              -78.15    77.81             3.76
# kodiak               -152.41     33.8             9.24
# mahebourg               57.7     75.2              4.7
# parfino                31.65    27.32             6.22
# tasiilaq              -37.64     15.8             2.24
# kulhudhuffushi         73.07    80.65             8.12
# vostok                135.88   -17.51             1.74
# saint-francois        -61.27     80.6             9.17
# san nicolas            120.6       68             2.24
# hilo                 -155.09     75.2             5.82
# ascension             -63.08    76.95             2.08
# katra                  74.95     41.9             2.98
# aksu                   80.26     9.32             0.63
# san-pedro              -6.64     82.4             6.93
# tuktoyaktuk          -133.04      8.6            13.87
# iqaluit               -68.51     28.4            14.99
# hithadhoo              73.08       82            12.59
# codajas               -62.06    79.02             4.76
# bethel                -73.41     42.8             3.36
# rawson                 -65.1    54.27            13.49
#
# [88 rows x 9 columns]

# %%
# Formatting citySample dataframe
    #drop cases where row is all NaN just in case
citySample_df['Max Temp'].dropna(axis=0, inplace=True)

        #format date from unix timestamp 
citySample_df['TimeStamp'] = pd.to_datetime(citySample_df['TimeStamp'], unit='s')

# mahebourg                83   -20.41      57.7     75.2              4.7
# parfino                  93    57.97     31.65    27.32             6.22
# tasiilaq                 47    65.61    -37.64     15.8             2.24
# kulhudhuffushi          100     6.62     73.07    80.65             8.12
# vostok                   72    46.49    135.88   -17.51             1.74
# saint-francois           74    16.25    -61.27     80.6             9.17
# san nicolas              94    18.17     120.6       68             2.24
# hilo                     50    19.73   -155.09     75.2             5.82
# ascension                91    -15.7    -63.08    76.95             2.08
# katra                    69    32.98     74.95     41.9             2.98
# aksu                     66    41.12     80.26     9.32             0.63
# san-pedro                83     4.75     -6.64     82.4             6.93
# tuktoyaktuk              92    69.45   -133.04      8.6            13.87
# iqaluit                  92    63.75    -68.51     28.4            14.99
# hithadhoo               100     -0.6     73.08       82            12.59
# codajas                  90    -3.84    -62.06    79.02             4.76
# bethel                   47    41.37    -73.41     42.8             3.36
# rawson                   91    -43.3     -65.1    54.27            13.49
#
# [88 rows x 9 columns]

# %%
#Scatterplot of Temperature (F) vs. Latitude
sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Max Temp'], edgecolor='black', alpha=0.5)

#Set titles and font sizes
plt.title('City Max Temperature vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Max Temperature (F)', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Scatterplot of Humidity (%) vs. Latitude

sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Humidity'], edgecolor='black', alpha=0.5)

#Set titles and font sizes
plt.title('City Humidity vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Humidity (%)', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#Scatterplot of Cloudiness (%) vs. Latitude

sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Cloudiness'], edgecolor='black', alpha=0.5)

#Set titles
plt.title('City Cloudiness vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Cloudiness', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Scatterplot of Wind Speed (mph) vs. Latitude

sns.set_style('dark')

# Set figuresize, grid, and plot scatterplot
fig, ax = plt.subplots(figsize=(11.6, 8.25))
ax.grid(linestyle='-', linewidth=1)
fig = plt.scatter(x=citySample_df['Latitude'], y=citySample_df['Wind Speed (mph)'], edgecolor='black', alpha=0.5)

# Set titles
plt.title('City Wind Speed vs. Latitude' + ' (' + str(citySample_df['Date'].iloc[0]) + ')', fontsize = 16)
plt.xlabel('Latitude', fontsize = 14)
plt.ylabel('Wind Speed (mph)', fontsize = 14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
